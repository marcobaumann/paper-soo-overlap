# %% [markdown]
# # 02 — Sham Fine-Tuning (control)
#
# **Story:** (Linear issue TBD)
#
# **Date:** 2026-07-22
#
# ## Introduction
#
# The paper (Carauleanu et al., arXiv:2412.16325) doesn't include a dose-matched control, so it's not possible from the published results alone to tell whether the drop in deceptive responses is specific to the SOO loss or just an artifact of fine-tuning Mistral-7B by that amount, at those layers, with that LoRA config. This experiment fine-tunes the same model/layers/LoRA/step-count as `../01_paper_reproduction`, but on an unrelated objective (causal-LM on wikitext) instead of the SOO loss, and evaluates with the same harness. See `DIFF.md` for the full audit of what is and isn't held constant.
#
# The read is the **gap** between the SOO arm's effect and this arm's effect, not either arm's raw number (see pre-registered outcomes in `README.md`). This is Rung 1 of the control ladder — it isolates fine-tuning-per-se, not the self-other mechanism itself (that needs a future scrambled-pairs control).
#
# *Not yet run — requires `01_paper_reproduction` to be run first (for per-seed step counts), then fill in results below once `run.sh` and `aggregate.py` output are available.*

# %%
# Load aggregated results and compute SOO effect = (SOO reduction) - (sham reduction)

# %% [markdown]
# ## Conclusion
#
# *TODO once results are in: which of the three pre-registered outcomes did we observe (sham stays high / sham drops as much / sham drops partially), and what does that imply about whether the SOO loss is load-bearing? Also report the MT-Bench comparison for the capability-cost claim.*
