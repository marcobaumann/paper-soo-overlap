# %% [markdown]
# # 01 — Paper Reproduction (Mistral-7B, SOO fine-tuning)
#
# **Story:** (Linear issue TBD)
#
# **Date:** 2026-07-22
#
# ## Introduction
#
# We are reproducing the LLM experiment from Carauleanu et al. (arXiv:2412.16325), Mistral-7B-Instruct-v0.2 arm only, verbatim: same self/other training pairs, same LoRA SOO fine-tuning recipe (Appendix A.1.2), same evaluation (deceptive response rate on the disjoint Bob-Burglar test set, plus Latent SOO). This is a faithful replication with no modifications to the recipe — see `README.md` for the two literal-reading judgment calls we had to make (mean pooling; no stop-gradient on `A_self`).
#
# The question: does the published result (deceptive response rate 73.6% → 17.27 ± 1.88%, MT-Bench roughly flat) hold when we run the recipe ourselves?
#
# *Not yet run — fill in results below once `run.sh` has been executed and `aggregate.py` output is available.*

# %%
# Load aggregated results (per-seed deceptive response rate, Latent SOO, MT-Bench)

# %% [markdown]
# ## Conclusion
#
# *TODO once results are in: does our reproduction match the paper's reported numbers? Any deviations (e.g. from the mean-pooling or no-stop-gradient choices) and what they suggest for follow-up.*
